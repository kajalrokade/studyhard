# %% [markdown]
# Decorators
#
# Decorators are a powerful and flexible feature in python that allows you to modify the behavior of a function or class method . they are commonly used to add functionality to functions or methods without modifying thier actual code. This lesson covers the basics of decorators including how to create and use them.

# %% [markdown]
# ### Function copy
# ### Closures
# ### Decorators

# %%
### function copy
def welcome():
    return "Hello Welcome to the world of kajal"

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# Hello Welcome to the world of kajal
# Hello Welcome to the world of kajal

# %%
### Closures functions

def main_welcome(msg):
    def sub_welcome():
        print("Welcome to the advnaced python concepts")
        print(msg)

        print("Learn this concepts properly")


    return sub_welcome()

# %%
main_welcome("Hello Everyone")
# Out:
# Welcome to the advnaced python concepts
# Hello Everyone
# Learn this concepts properly

# %%
# In closures we can also pass the methods to the methods

def main_welcome(func):
    def sub_welcome():
        print("Welcome to the advnaced python concepts")
        func("Hello Everyone")

        print("Learn this concepts properly")


    return sub_welcome()

# %%
main_welcome(print)
# Out:
# Welcome to the advnaced python concepts
# Hello Everyone
# Learn this concepts properly

# %%
### Decorators

def main_welcome(func):
    def sub_welcome():
        print("Welcome to the advnaced python concepts")
        func()
        print("Learn this concepts properly")


    return sub_welcome()

# %%
def course_introduction():
    print("this is an advanced python course")

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advnaced python concepts
# this is an advanced python course
# Learn this concepts properly

# %%
@main_welcome
def course_introduction():
    print("this is an advanced python course")
# Out:
# Welcome to the advnaced python concepts
# this is an advanced python course
# Learn this concepts properly

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 course_introduction()
#
# TypeError: 'NoneType' object is not callable
