# %%
print(1+3)
# Out:
# 4

# %%
import numpy as np
arr= np.array([1,2,3,4,5])
print(arr**3)
# Out:
# [  1   8  27  64 125]

# %%
## Basic Syntax Rules in python 

## single line comment
'''
this is the multiline comments 
'''
# Pyhton is case sensitive 

name="kajal"
Name="Rokade"

print(name) 
print(Name)
# Out:
# kajal
# Rokade

# %%
# Line continutation
total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
# multiple statrments on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
# Understand semantics in python
# variable assignment 
age=32 ## age is an integer
name="Kajal" ##name is a string

type(age)
# Out:
# int

# %%
# type Inference
variable=10
print(type(variable))


variable="Kajal"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Name error
 a=b
# Out:
#   Cell In[24], line 2
#     a=b
#     ^
# IndentationError: unexpected indent

# %%
# Code indentation

if True:
    print("Correct Indentation")
    if False:
       print("this out print")
    print("this will print")
print("Outside the if block")
# Out:
# Correct Indentation
# this will print
# Outside the if block

# %%
## Declaring and Assigning variables

age=32
height=5.4
name="krish"
is_student=True

## printing the variables
print("age:",age)
print("height:",height)
print("Name:",name)
# Out:
# age: 32
# height: 5.4
# Name: krish

# %%
## Naming Conventions

## Variable should be descriptive
## They must start with the letter, or '_'  and can containg letter number or '_' in between
## Varibales name are case sensitive


## Valid variable names

age=28
_name="Kajal"
is_student=True
sub_3_maths=50

# all the above are valid varible names following the rule

# %%
# Invalid varibale name

99age=28
$name="kajal"
first-name="kajal"


# above all the invalid variable names
# Out:
#   Cell In[32], line 3
#     99age=28
#      ^
# SyntaxError: invalid decimal literal

# %%
## variable types
# python is dynamically type, type of variable is determined at runtime

age=25 #int
height=5.4 #float
name="Kajal" #str
is_student= True # bool


print(type(name))
# Out:
# <class 'str'>

# %%
## Type Checking and Conversion 
type(height)
# Out:
# <class 'int'>

# %%
age=25 
print(type(age))
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="Kajal"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 name="Kajal"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Kajal'

# %%
height=5.4
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
## Dynamic Typing
## Python allows the type of a variable to change as the program executes
var=10
print(var,type(var))

var="hello"
print(var,type(var))

var=5.4
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 5.4 <class 'float'>

# %%
## Input

age=int(input("Enter the age"))
print(age,type(age))
# Out:
# 30 <class 'int'>

# %%
## Simple Calculator
num1= float(input("Enter the first number"))
num2= float(input("Enter the second number"))

print("sum=", num1+num2)
print("division=", num1-num2)
print("multiplication=", num1*num2)
print("division=", num1/ num2)
# Out:
# sum= 23.0
# division= 17.0
# multiplication= 60.0
# division= 6.666666666666667

# %%
## Data types
## int, float, str, bool

# Data type ensures that data is stored in an efficient way
# they help in performing correct operation on data
# Proper use of data types can prevent errors and bugs in the program

# %%
## Arithmetic Operators

a=10
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b) #floor division

print(a%b)
print(a**b)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# ## comparison Operator

# %%
x= True
y=False

result= x and y
print(result)


result = x or y
print(result)


print(not x)
# Out:
# False
# True
# False
