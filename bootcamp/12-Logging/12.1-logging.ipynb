# %% [markdown]
# Logging

# %%
import logging as log


## configure the basic logging settings

log.basicConfig(level=log.DEBUG)


## log messages with different severity levels

log.debug("This is the debug")

log.info("THis is info")

log.warning("this is the warning")


log.error("This is error")

log.critical("This is critical message")

# %%
## configuring logging
import logging

logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=log.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
    )


logging.debug("This is the debug")
logging.info("THis is info")

logging.warning("this is the warning")


logging.error("This is error")

logging.critical("This is critical message")

# %%
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 1150, in emit
#     msg = self.format(record)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 998, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 713, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#                      ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 650, in formatTime
#     s = time.strftime(datefmt, ct)
# ValueError: Invalid format string
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kajal\AppData\Local\Temp\ipykernel_9372\2847330690.py", line 1, in <module>
#     log.debug("This is the debug")
# Message: 'This is the debug'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 1150, in emit
#     msg = self.format(record)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 998, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 713, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#                      ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 650, in formatTime
#     s = time.strftime(datefmt, ct)
# ValueError: Invalid format string
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kajal\AppData\Local\Temp\ipykernel_9372\2847330690.py", line 2, in <module>
#     log.info("THis is info")
# Message: 'THis is info'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 1150, in emit
#     msg = self.format(record)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 998, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 713, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#                      ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 650, in formatTime
#     s = time.strftime(datefmt, ct)
# ValueError: Invalid format string
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kajal\AppData\Local\Temp\ipykernel_9372\2847330690.py", line 4, in <module>
#     log.warning("this is the warning")
# Message: 'this is the warning'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 1150, in emit
#     msg = self.format(record)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 998, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 713, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#                      ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 650, in formatTime
#     s = time.strftime(datefmt, ct)
# ValueError: Invalid format string
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kajal\AppData\Local\Temp\ipykernel_9372\2847330690.py", line 7, in <module>
#     log.error("This is error")
# Message: 'This is error'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 1150, in emit
#     msg = self.format(record)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 998, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 713, in format
#     record.asctime = self.formatTime(record, self.datefmt)
#                      ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\logging\__init__.py", line 650, in formatTime
#     s = time.strftime(datefmt, ct)
# ValueError: Invalid format string
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\kajal\studyhard\bootcamp\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kajal\AppData\Local\Temp\ipykernel_9372\2847330690.py", line 9, in <module>
#     log.critical("This is critical message")
# Message: 'This is critical message'
# Arguments: ()
