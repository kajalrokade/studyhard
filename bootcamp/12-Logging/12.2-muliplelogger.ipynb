# %% [markdown]
# Loggin with multiple logger

# %%
import logging


### create a logger for module1

logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)


logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)


logging.basicConfig(
       level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
    )

# %%
# log messagee with diffrent loggers

logger1.debug("this si debug message for module1")


logger2.warning("This is a warning message for module2")


logger2.error("This is error message")
# Out:
# 2026-05-19 17:13:44-module1-DEBUG-this si debug message for module1
# 2026-05-19 17:13:44-module2-WARNING-This is a warning message for module2
# 2026-05-19 17:13:44-module2-ERROR-This is error message
